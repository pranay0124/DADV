# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Find the average rank of the 10 most popular movies between 2000-2009 (inclusive)

# %%
ratings = pd.read_csv("titleRatings.tsv", delimiter = '\t')

# %%
ratings.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.6      1557
# 1  tt0000002            6.1       187
# 2  tt0000003            6.5      1220
# 3  tt0000004            6.2       113
# 4  tt0000005            6.1      1949

# %%
basics = pd.read_csv("titleBasics.tsv", delimiter = '\t')
# Out:
# C:\Users\prasamsa\AppData\Roaming\Python\Python37\site-packages\IPython\core\interactiveshell.py:3057: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
basics.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#    isAdult startYear endYear runtimeMinutes                    genres
# 0        0      1894      \N              1         Documentary,Short
# 1        0      1892      \N              5           Animation,Short
# 2        0      1892      \N              4  Animation,Comedy,Romance
# 3        0      1892      \N             \N           Animation,Short
# 4        0      1893      \N              1              Comedy,Short

# %%
basics['startYear'] = pd.to_numeric(basics['startYear'], errors='coerce')

# %%
year = basics[(basics.startYear >= 2000) & (basics.startYear <= 2009)]
year
# Out:
#             tconst  titleType            primaryTitle  \
# 18039    tt0018295      short       El puño de hierro
# 34815    tt0035423      movie          Kate & Leopold
# 74221    tt0075779      short  Bozorgdasht-e mo'Allem
# 77560    tt0079204      movie        Case #1, Case #2
# 86834    tt0088751      movie       The Naked Monster
# ...            ...        ...                     ...
# 6393205  tt9916794  tvEpisode           Episode #2.33
# 6393206  tt9916796  tvEpisode           Episode #2.34
# 6393207  tt9916798  tvEpisode           Episode #2.36
# 6393208  tt9916800  tvEpisode           Episode #2.35
# 6393210  tt9916804  tvEpisode           Episode #2.37
#
#                                              originalTitle  isAdult  \
# 18039                                    El puño de hierro        0
# 34815                                       Kate & Leopold        0
# 74221                               Bozorgdasht-e mo'Allem        0
# 77560    Ghazieh-e Shekl-e Aval, Ghazieh-e Shekl-e Dou Wom        0
# 86834                                    The Naked Monster        0
# ...                                                    ...      ...
# 6393205                                      Episode #2.33        0
# 6393206                                      Episode #2.34        0
# 6393207                                      Episode #2.36        0
# 6393208                                      Episode #2.35        0
# 6393210                                      Episode #2.37        0
#
#          startYear endYear runtimeMinutes                  genres
# 18039       2004.0      \N             40      Action,Drama,Short
# 34815       2001.0      \N            118  Comedy,Fantasy,Romance
# 74221       2004.0      \N             20                   Short
# 77560       2004.0      \N             53       Documentary,Drama
# 86834       2005.0      \N            100    Comedy,Horror,Sci-Fi
# ...            ...     ...            ...                     ...
# 6393205     2009.0      \N             \N     Action,Drama,Family
# 6393206     2009.0      \N             \N     Action,Drama,Family
# 6393207     2009.0      \N             \N     Action,Drama,Family
# 6393208     2009.0      \N             \N     Action,Drama,Family
# 6393210     2009.0      \N             \N     Action,Drama,Family
#
# [1341103 rows x 9 columns]

# %%
merge = pd.merge(year, ratings, on='tconst')
merge.head()
# Out:
#       tconst titleType            primaryTitle  \
# 0  tt0018295     short       El puño de hierro
# 1  tt0035423     movie          Kate & Leopold
# 2  tt0075779     short  Bozorgdasht-e mo'Allem
# 3  tt0079204     movie        Case #1, Case #2
# 4  tt0088751     movie       The Naked Monster
#
#                                        originalTitle  isAdult  startYear  \
# 0                                  El puño de hierro        0     2004.0
# 1                                     Kate & Leopold        0     2001.0
# 2                             Bozorgdasht-e mo'Allem        0     2004.0
# 3  Ghazieh-e Shekl-e Aval, Ghazieh-e Shekl-e Dou Wom        0     2004.0
# 4                                  The Naked Monster        0     2005.0
#
#   endYear runtimeMinutes                  genres  averageRating  numVotes
# 0      \N             40      Action,Drama,Short            6.7        27
# 1      \N            118  Comedy,Fantasy,Romance            6.4     75531
# 2      \N             20                   Short            6.5        22
# 3      \N             53       Documentary,Drama            7.8       424
# 4      \N            100    Comedy,Horror,Sci-Fi            5.6       236

# %%
popularSet = merge.sort_values('numVotes', ascending = False)

# %%
print(popularSet.head(10)['averageRating'].mean())
# Out:
# 8.690000000000001

# %% [markdown]
# ### Find the year in the 1900s when the average rank increased the most, compared to the previous year. (Ignore movies with votes < 1000)

# %%
votes = ratings[ratings['numVotes'] > 1000]
votes
# Out:
#             tconst  averageRating  numVotes
# 0        tt0000001            5.6      1557
# 2        tt0000003            6.5      1220
# 4        tt0000005            6.1      1949
# 7        tt0000008            5.4      1678
# 9        tt0000010            6.9      5586
# ...            ...            ...       ...
# 1001324  tt9892204            7.4      1422
# 1001437  tt9898836            9.9      8313
# 1001510  tt9900782            8.7      4627
# 1001598  tt9906260           10.0     23252
# 1001643  tt9908860            6.7      1071
#
# [52655 rows x 3 columns]

# %%
new = pd.merge(votes, basics, on = 'tconst')

# %%
year = new[(new['startYear'] >= 1900) & (new['startYear'] < 2000)]

# %%
out = year.groupby('startYear').agg(
    mp = ('averageRating', np.mean)
).reset_index()

# %%
maxi = 0
yr = 0
for i in range(1, len(out)):
    v1 = out.loc[i, 'mp']
    v2 = out.loc[i-1, 'mp']
    temp = abs(v1 - v2)
    if temp> maxi:
        maxi = temp
        yr = out.loc[[i], ['startYear']]
yr
# Out:
#    startYear
# 3     1903.0

# %% [markdown]
# ### Find the expected average rank for 2013 using linear regression. How good is this regression? (Ignore movies with votes < 1000.)

# %%
data = pd.merge(ratings, basics, on = 'tconst')
data
# Out:
#             tconst  averageRating  numVotes  titleType  \
# 0        tt0000001            5.6      1557      short
# 1        tt0000002            6.1       187      short
# 2        tt0000003            6.5      1220      short
# 3        tt0000004            6.2       113      short
# 4        tt0000005            6.1      1949      short
# ...            ...            ...       ...        ...
# 1001869  tt9916576            5.9         7  tvEpisode
# 1001870  tt9916578            9.2        12  tvEpisode
# 1001871  tt9916720            5.3        43      short
# 1001872  tt9916766            6.7        11  tvEpisode
# 1001873  tt9916778            6.9        16  tvEpisode
#
#                       primaryTitle              originalTitle  isAdult  \
# 0                       Carmencita                 Carmencita        0
# 1           Le clown et ses chiens     Le clown et ses chiens        0
# 2                   Pauvre Pierrot             Pauvre Pierrot        0
# 3                      Un bon bock                Un bon bock        0
# 4                 Blacksmith Scene           Blacksmith Scene        0
# ...                            ...                        ...      ...
# 1001869           Destinee's Story           Destinee's Story        0
# 1001870  The Trial of Joan Collins  The Trial of Joan Collins        0
# 1001871                  The Nun 2                  The Nun 2        0
# 1001872             Episode #10.15             Episode #10.15        0
# 1001873                     Escape                     Escape        0
#
#          startYear endYear runtimeMinutes                      genres
# 0           1894.0      \N              1           Documentary,Short
# 1           1892.0      \N              5             Animation,Short
# 2           1892.0      \N              4    Animation,Comedy,Romance
# 3           1892.0      \N             \N             Animation,Short
# 4           1893.0      \N              1                Comedy,Short
# ...            ...     ...            ...                         ...
# 1001869     2019.0      \N             85                  Reality-TV
# 1001870     2019.0      \N             \N  Adventure,Biography,Comedy
# 1001871     2019.0      \N             10       Comedy,Horror,Mystery
# 1001872     2019.0      \N             43           Family,Reality-TV
# 1001873     2019.0      \N             \N                       Drama
#
# [1001874 rows x 11 columns]

# %%
vote = data[data['numVotes']>= 1000]
vote
# Out:
#             tconst  averageRating  numVotes  titleType  \
# 0        tt0000001            5.6      1557      short
# 2        tt0000003            6.5      1220      short
# 4        tt0000005            6.1      1949      short
# 7        tt0000008            5.4      1678      short
# 9        tt0000010            6.9      5586      short
# ...            ...            ...       ...        ...
# 1001324  tt9892204            7.4      1422  tvEpisode
# 1001437  tt9898836            9.9      8313  tvEpisode
# 1001510  tt9900782            8.7      4627      movie
# 1001598  tt9906260           10.0     23252  tvEpisode
# 1001643  tt9908860            6.7      1071   tvSeries
#
#                                    primaryTitle  \
# 0                                    Carmencita
# 2                                Pauvre Pierrot
# 4                              Blacksmith Scene
# 7        Edison Kinetoscopic Record of a Sneeze
# 9                           Exiting the Factory
# ...                                         ...
# 1001324       Weekend Box Office: March 8 to 10
# 1001437                            Perfect Game
# 1001510                                  Kaithi
# 1001598                                    Hero
# 1001643                              Blown Away
#
#                                   originalTitle  isAdult  startYear endYear  \
# 0                                    Carmencita        0     1894.0      \N
# 2                                Pauvre Pierrot        0     1892.0      \N
# 4                              Blacksmith Scene        0     1893.0      \N
# 7        Edison Kinetoscopic Record of a Sneeze        0     1894.0      \N
# 9           La sortie de l'usine Lumière à Lyon        0     1895.0      \N
# ...                                         ...      ...        ...     ...
# 1001324       Weekend Box Office: March 8 to 10        0     2019.0      \N
# 1001437                            Perfect Game        0     2019.0      \N
# 1001510                                  Kaithi        0     2019.0      \N
# 1001598                                    Hero        0     2019.0      \N
# 1001643                              Blown Away        0     2019.0      \N
#
#         runtimeMinutes                      genres
# 0                    1           Documentary,Short
# 2                    4    Animation,Comedy,Romance
# 4                    1                Comedy,Short
# 7                    1           Documentary,Short
# 9                    1           Documentary,Short
# ...                ...                         ...
# 1001324              1                        News
# 1001437             24  Action,Adventure,Animation
# 1001510            145             Action,Thriller
# 1001598             24  Action,Adventure,Animation
# 1001643             \N                  Reality-TV
#
# [52686 rows x 11 columns]

# %%
out1 = vote.groupby('startYear').agg(
    avg = ('averageRating', np.mean)
).reset_index()

# %%
out1
# Out:
#      startYear       avg
# 0       1874.0  6.900000
# 1       1878.0  7.400000
# 2       1888.0  6.533333
# 3       1890.0  5.000000
# 4       1891.0  5.100000
# ..         ...       ...
# 128     2015.0  7.185780
# 129     2016.0  7.173071
# 130     2017.0  7.199403
# 131     2018.0  7.162417
# 132     2019.0  7.372226
#
# [133 rows x 2 columns]

# %%
out1 = out1[out1.startYear != 2013]
out1
# Out:
#      startYear       avg
# 0       1874.0  6.900000
# 1       1878.0  7.400000
# 2       1888.0  6.533333
# 3       1890.0  5.000000
# 4       1891.0  5.100000
# ..         ...       ...
# 128     2015.0  7.185780
# 129     2016.0  7.173071
# 130     2017.0  7.199403
# 131     2018.0  7.162417
# 132     2019.0  7.372226
#
# [132 rows x 2 columns]

# %%
from sklearn.linear_model import LinearRegression
x = out1['startYear'].values.reshape(-1,1)
y = out1['avg'].values.reshape(-1,1)

# %%
model = LinearRegression().fit(x,y)

# %%
xtest = np.array([2013]).reshape(-1,1)
y_pred = model.predict(xtest)
print(y_pred)
# Original average rating for 2013	7.069302
# Out:
# [[6.97846597]]

# %%
import matplotlib.pyplot as plt  # To visualize

# %%
temp_pred = model.predict(x)
plt.scatter(x, y)
plt.plot(x, temp_pred, color='red')
plt.show()

# %% [markdown]
# ### Find the correlation between rank and votes for each year in the 1900s. By how much did the correlation coefficient grow each year? How good is this regression?

# %%
corryear = basics[(basics['startYear']>= 1900) & (basics['startYear'] < 2000)]

# %%
corrData = pd.merge(ratings, corryear, on='tconst')
corrData
# Out:
#            tconst  averageRating  numVotes  titleType  \
# 0       tt0000160            5.8         8      short
# 1       tt0000265            4.6        93      short
# 2       tt0000269            5.2        91      short
# 3       tt0000271            7.3         6      short
# 4       tt0000272            5.6       627      short
# ...           ...            ...       ...        ...
# 345687  tt9909456            6.2         6      video
# 345688  tt9909498            7.6         9      video
# 345689  tt9909520            7.3         6      video
# 345690  tt9909866            5.4         5      video
# 345691  tt9914702            7.4         5  tvEpisode
#
#                                              primaryTitle  \
# 0                                The Last Days of Pompeii
# 1                                         Above the Limit
# 2       Army Life; or, How Soldiers Are Made: Mounted ...
# 3                          Arrivée de Pierette et Pierrot
# 4                             As Seen Through a Telescope
# ...                                                   ...
# 345687             The Moody Blues: Nights in White Satin
# 345688                 Pink Floyd: Interstellar Overdrive
# 345689                          Pink Floyd: Nick's Boogie
# 345690                                               Nora
# 345691                      Episode dated 5 February 1988
#
#                                  originalTitle  isAdult  startYear endYear  \
# 0                     The Last Days of Pompeii        0     1900.0      \N
# 1                              Above the Limit        0     1900.0      \N
# 2                                    Army Life        0     1900.0      \N
# 3               Arrivée de Pierette et Pierrot        0     1900.0      \N
# 4                  As Seen Through a Telescope        0     1900.0      \N
# ...                                        ...      ...        ...     ...
# 345687  The Moody Blues: Nights in White Satin        0     1967.0      \N
# 345688      Pink Floyd: Interstellar Overdrive        0     1967.0      \N
# 345689               Pink Floyd: Nick's Boogie        0     1967.0      \N
# 345690                                    Nora        0     1985.0      \N
# 345691           Episode dated 5 February 1988        0     1988.0      \N
#
#        runtimeMinutes                      genres
# 0                  \N                 Drama,Short
# 1                  \N                Comedy,Short
# 2                  \N           Documentary,Short
# 3                  \N                       Short
# 4                   1                Comedy,Short
# ...               ...                         ...
# 345687              4                 Music,Short
# 345688             17                 Music,Short
# 345689             12                 Music,Short
# 345690             45  Action,Adventure,Animation
# 345691             \N                          \N
#
# [345692 rows x 11 columns]

# %%
# dic = {}
# for i in range(1900, 2000):
#     rat = []
#     vot = []
#     for j in range(len(corrData)):
#         if corrData['startYear'][j] == i:
#             rat.append(corrData['averageRating'][j])
#             vot.append(corrData['numVotes'][j])
#     dic[i] = [rat, vot]

# %%
years = list(corrData['startYear'].unique())
yearCorr = pd.DataFrame()
for year in years:
    X=corrData[corrData['startYear']==year].iloc[:,[1,2]]
    corr = X.corr()
    corr = corr['averageRating'][1]
    newRow = {'Correlation':corr,'Year':year}
    yearCorr = yearCorr.append(newRow, ignore_index=True)
yearCorr = yearCorr.reindex(columns=['Year', 'Correlation'])
yearCorr
# Out:
#       Year  Correlation
# 0   1900.0     0.166932
# 1   1901.0     0.256151
# 2   1904.0     0.236146
# 3   1903.0     0.174144
# 4   1902.0     0.187607
# ..     ...          ...
# 95  1999.0     0.029347
# 96  1998.0     0.022265
# 97  1994.0     0.035318
# 98  1997.0     0.021013
# 99  1996.0     0.007475
#
# [100 rows x 2 columns]

# %%
import matplotlib.pyplot
import pylab
matplotlib.pyplot.scatter(yearCorr['Year'],yearCorr['Correlation'])

# %%
plt.bar(np.arange(len(yearCorr['Year'])), yearCorr['Correlation'])
# plt.xticks(np.arange(len(yearCorr['Year'])), yearCorr['Year'])
# Out:
# <BarContainer object of 100 artists>

# %%
import seaborn as sns
sns.pairplot(yearCorr, x_vars='Year', y_vars='Correlation', size=7, aspect=0.7, kind='reg')
