# %%
import pandas as pd
import numpy as np
import random
import glob
import csv, os

# %%
def is_file_empty(file_path):
    return os.path.exists(file_path) and os.stat(file_path).st_size == 0

# %%
count = 1
df = pd.DataFrame()
for files in glob.glob('E:\\DADV\\BSE-Assignment\\Datasets\\*.csv'):
    if count == 10:
        break
    f=open(files, 'r')
    name = os.path.basename(f.name).replace(".csv","")
    if is_file_empty("E:\\DADV\\BSE-Assignment\\Datasets\\"+name+".csv"):
        continue
    data = pd.read_csv(f)
    gain = (data.at[data.shape[0]-1, "Close Price"] / data.at[0,"Close Price"]) - 1
#     gain = (close[len(close)-1]/close[0])-1
    row = {'Code': name, 'Gain': gain}
    df = df.append(row, ignore_index=True)
    count = count + 1
    f.close()

# %%
df
# Out:
#      Code      Gain
# 0  500002 -0.007917
# 1  505358  0.475936
# 2  506260  0.249711
# 3  511359  0.739800
# 4  511696  0.000000
# 5  512344  0.056022
# 6  513566  1.334821
# 7  514165 -0.031377
# 8  519279  0.709677

# %%
df = df.sort_values("Gain", ascending=False)
df
# Out:
#      Code      Gain
# 6  513566  1.334821
# 3  511359  0.739800
# 8  519279  0.709677
# 1  505358  0.475936
# 2  506260  0.249711
# 5  512344  0.056022
# 4  511696  0.000000
# 0  500002 -0.007917
# 7  514165 -0.031377

# %% [markdown]
# ### Analysis

# %%
icici = pd.read_csv("icici.csv")

# %%
dic = {}
count = 1
for files in glob.glob("E:\\DADV\\BSE-Assignment\\Datasets\\*.csv"):
    f=open(files, 'r')
    if count == 10:
        break
    name = os.path.basename(f.name).replace(".csv","")
    if is_file_empty("E:\\DADV\\BSE-Assignment\\Datasets\\"+name+".csv"):
        continue
    data = pd.read_csv(f)
    dic[name] = list(data["Close Price"])
    count = count + 1
    f.close()

#making all equal sized lists (for correlation to happen)
dic["icici"] = list(icici["Close Price"])
max_length = 0
for lis in dic.values():
    max_length = max(max_length, len(lis))
for lis in dic.values():
    lis += [0.0] * (max_length - len(lis))

#finding the correlation
df = pd.DataFrame()
for each1 in dic.keys():
    corr = np.corrcoef(dic.get("icici"), dic.get(each1))[0][1]
    row = {'Code': each1, 'Corr': corr}
    df = df.append(row, ignore_index=True)
df
# Out:
#      Code      Corr
# 0  500002  0.325005
# 1  505358 -0.564644
# 2  506260  0.000471
# 3  511359  0.521522
# 4  511696  0.651220
# 5  512344  0.215820
# 6  513566 -0.007471
# 7  514165  0.008308
# 8  519279  0.766022
# 9   icici  1.000000

# %%
df = df.sort_values("Corr", ascending=False)
df
# Out:
#      Code      Corr
# 9   icici  1.000000
# 8  519279  0.766022
# 4  511696  0.651220
# 3  511359  0.521522
# 0  500002  0.325005
# 5  512344  0.215820
# 7  514165  0.008308
# 2  506260  0.000471
# 6  513566 -0.007471
# 1  505358 -0.564644

# %%
# count = 1
# df = pd.DataFrame()
# for files in glob.glob('E:\\DADV\\BSE-Assignment\\Datasets\\*.csv'):
#     if count == 10:
#         break
#     f=open(files, 'r')
#     name = os.path.basename(f.name).replace(".csv","")
#     if is_file_empty("E:\\DADV\\BSE-Assignment\\Datasets\\"+name+".csv"):
#         continue
#     data = pd.read_csv(f)
    
#     companyList = data["Close Price"]
#     iciciList = icici["Close Price"]
#     max_length = max(len(companyList), len(iciciList))
#     companyList += [0.0] * (max_length - len(data["Close Price"]))
#     iciciList += [0.0] * (max_length - len(icici["Close Price"]))
    
#     corr = np.corrcoef(companyList, iciciList) [0][1]
#     row = {'Code': name, 'Corr': corr}
#     df = df.append(row, ignore_index=True)
#     count = count + 1
#     f.close()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-c5e1c03703bf> in <module>
#      14     max_length = max(len(companyList), len(iciciList))
#      15     companyList += [0.0] * (max_length - len(data["Close Price"]))
# ---> 16     iciciList += [0.0] * (max_length - len(icici["Close Price"]))
#      17
#      18     corr = np.corrcoef(companyList, iciciList) [0][1]
#
# C:\Python\lib\site-packages\pandas\core\ops\__init__.py in f(self, other)
#     823
#     824         def f(self, other):
# --> 825             result = method(self, other)
#     826
#     827             # this makes sure that we are aligned like the input
#
# C:\Python\lib\site-packages\pandas\core\ops\__init__.py in wrapper(left, right)
#    1046
#    1047         with np.errstate(all="ignore"):
# -> 1048             result = na_op(lvalues, rvalues)
#    1049         return construct_result(
# ...
